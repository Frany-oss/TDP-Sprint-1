# %%
# %%bash
# conda create -n dcton python=3.6
# conda activate dcton
# conda install pytorch==1.0.10 torchvision==0.3.0 cuda100
# pip install tensorboardX
# pip install opencv-python
# pip install imdb
# pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# bash: line 1: conda: command not found
# bash: line 2: conda: command not found
# bash: line 3: conda: command not found
# ERROR: Could not find a version that satisfies the requirement imdb (from versions: none)
# ERROR: No matching distribution found for imdb

# %%
# !git clone https://github.com/ChongjianGE/DCTON
# Out:
# Cloning into 'DCTON'...
# remote: Enumerating objects: 161, done.
# remote: Counting objects: 100% (161/161), done.
# remote: Compressing objects: 100% (124/124), done.
# remote: Total 161 (delta 40), reused 143 (delta 27), pack-reused 0
# Receiving objects: 100% (161/161), 3.16 MiB | 12.26 MiB/s, done.
# Resolving deltas: 100% (40/40), done.
